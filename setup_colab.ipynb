# %% [markdown]
# <a href="https://colab.research.google.com/github/rajarajanponraj/ATSM_Framework/blob/main/setup_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ATSM Framework Setup for Google Colab
# Run the cells below in order to securely download the dataset, clone the repository, and run the framework without crashing the instance.

# %%
import os

# 1. Enter your new Kaggle API Token (starts with KGAT_)
kaggle_token = input("Please paste your Kaggle API Token (e.g. KGAT_...): ")

# 2. Save the token as per Kaggle's new API requirements
os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)
access_token_path = os.path.expanduser("~/.kaggle/access_token")

with open(access_token_path, "w") as f:
    f.write(kaggle_token.strip())

os.chmod(access_token_path, 0o600)
print("Token saved successfully!")

# Ensure Kaggle CLI is up to date
# !pip install --upgrade kaggle > /dev/null

# Download the dataset
# !kaggle datasets download -d gogo827jz/davis-240c-datasets
# Out:
# Please paste your Kaggle API Token (e.g. KGAT_...): KGAT_e27dc54ea3fdea9ff88c913bb42e6cc3
# Token saved successfully!
# Dataset URL: https://www.kaggle.com/datasets/gogo827jz/davis-240c-datasets
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 7.91G/7.91G [01:10<00:00, 121MB/s]

# %%
# 3. Extract ONLY a single sequence to prevent Disk/RAM overload
# !rm -rf dataset/  # clean up previous failed attempts
# !unzip -q davis-240c-datasets.zip "shapes_6dof/*" -d dataset/
print("Extraction complete!")
# Out:
# Extraction complete!

# %%
# 4. Clone the ATSM_Framework GitHub repository
# %cd /content
# !rm -rf ATSM_Framework
# !git clone https://github.com/rajarajanponraj/ATSM_Framework.git
# %cd ATSM_Framework
# !pip install -r requirements.txt > /dev/null
print("Repository cloned and ready!")
# Out:
# /content
# Cloning into 'ATSM_Framework'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 25 (delta 9), reused 21 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 6.52 KiB | 6.52 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/ATSM_Framework
# Repository cloned and ready!

# %%
# 5. Run the optimized streaming ATSM framework
# !python main.py --dataset /content/dataset/shapes_6dof/
# Out:
# Starting Adaptive Temporal-Spatial Modulation (ATSM) Framework...
# Found 1356 frames in /content/dataset/shapes_6dof/
# Processing frame 0...
# Processing frame 50...
# Processing frame 100...
# Processing frame 150...
# Processing frame 200...
# Processing frame 250...
# Processing frame 300...
# Processing frame 350...
# Processing frame 400...
# Processing frame 450...
# Processing frame 500...
# Processing frame 550...
# Processing frame 600...
# Processing frame 650...
# Processing frame 700...
# Processing frame 750...
# Processing frame 800...
# Processing frame 850...
# Processing frame 900...
# Processing frame 950...
# Processing frame 1000...
# Processing frame 1050...
# Processing frame 1100...
# Processing frame 1150...
# Processing frame 1200...
# Processing frame 1250...
# Processing frame 1300...
# Processing frame 1350...
# ATSM Execution Completed.
